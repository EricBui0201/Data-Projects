# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x1 = np.arange(0,10,1)

# %%
x2 = np.linspace(0,5,10)

# %%
plt.plot(x1,x1)

# %%
plt.plot(x1,x2**2)

# %%
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
import numpy as np
x1 = np.arange(0,10,1)
x2 = np.linspace(0,5,10)
plt.plot(x1, x1, label='linear')
plt.plot(x1, x2**2, label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %%
# Creating a figure with 2 subplots
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x1,x2)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x1,x2**2)
ax2.set_title('COSINE PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

plt.show()

# %%
x = np.random.randn(10)
y = np.random.randn(10)
plt.scatter(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
labels = ['Vegetarians', 'Non-Vegetarians', 'Vegans']
sizes = [40, 45, 15]
explode = (0, 0.1, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# # SEABORN

# %% [markdown]
# Seaborn is a data visualization library that was created to complement matplotlib and it is closely integrated with pandas data structures. Some of the advantages of this library are:
#
# Streamlines the amount of code needed to write to create matplotlib visualizations
# Enables us to work with pandas dataframes which is a big advantage over matplotlib
# Provides specialized support for using categorical variables
# Has functions to examine relationships between multiple variables
# Provides convenient views onto the overall structure of complex datasets

# %%
import seaborn as sns

# %%
# %matplotlib inline
sns.set() # set all the format in seaborn in to jupyter notebook or matplot
plt.scatter(x,y)

# %%
import pandas as pd
data = pd.DataFrame([x1,x2**2]).T
data.columns = ['X','Y']
sns.lmplot('X','Y', data = data, fit_reg=1)  # we can also write: fit_reg = True or False

# %%
import os

# %%
os.chdir('/Users/linhdao/Ironhack/In Class/Week 2/vehicles')

# %%
df = pd.read_csv('vehicles.csv')

# %%
df.sample(5)
# Out:
#             Make               Model  Year  Engine Displacement  Cylinders  \
# 11104      Eagle               Talon  1991                  2.0        4.0
# 4879   Chevrolet              Camaro  1992                  5.0        8.0
# 20513        Kia              Optima  2007                  2.7        6.0
# 14525        GMC    C2500 Sierra 2WD  1989                  5.0        8.0
# 16298        GMC  Suburban V1500 4WD  1991                  5.7        8.0
#
#           Transmission                  Drivetrain             Vehicle Class  \
# 11104     Manual 5-spd           Front-Wheel Drive           Subcompact Cars
# 4879   Automatic 4-spd            Rear-Wheel Drive           Subcompact Cars
# 20513  Automatic 5-spd           Front-Wheel Drive              Midsize Cars
# 14525  Automatic 3-spd            Rear-Wheel Drive    Standard Pickup Trucks
# 16298  Automatic 4-spd  4-Wheel or All-Wheel Drive  Special Purpose Vehicles
#
# ...

# %%
sns.scatterplot(x='CO2 Emission Grams/Mile', y='Highway MPG', data=df)

# %%
sns.scatterplot(x='CO2 Emission Grams/Mile', y='Highway MPG', data=df, hue='Drivetrain')

# %%
sns.scatterplot(x='CO2 Emission Grams/Mile', y='Highway MPG', data=df, hue='Drivetrain', size = 'Cylinders')

# %%
sns.catplot(x='Highway MPG', y='Drivetrain', data=df, hue='Fuel Type', col='Cylinders')

# %%
sns.catplot(x='Highway MPG', y='Drivetrain', data=df, hue='Make', col='Fuel Type')

# %%
sns.catplot(y='Highway MPG', x='Drivetrain', data=df[:200], col='Fuel Type', kind='boxen')

# %%
df.boxplot(column = 'Combined MPG')

# %%
ax = sns.boxplot(x='Fuel Type', y='Combined MPG', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(0, 0, 'Premium'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'Premium and Electricity'),
#  Text(0, 0, 'Premium or E85'),
#  Text(0, 0, 'Premium Gas or Electricity'),
#  Text(0, 0, 'Gasoline or E85'),
#  Text(0, 0, 'Gasoline or natural gas'),
#  Text(0, 0, 'CNG'),
#  Text(0, 0, 'Regular Gas or Electricity'),
#  Text(0, 0, 'Midgrade'),
#  Text(0, 0, 'Regular Gas and Electricity'),
#  Text(0, 0, 'Gasoline or propane')]

# %%
sns.violinplot('Highway MPG', data=df)

# %%
df['CO2 Emission Grams/Mile'].hist(bins=50)

# %%
sns.distplot(df['CO2 Emission Grams/Mile'], bins=50)  # distribution plot

# %%
df.Drivetrain.value_counts().plot.bar()

# %%
ax = sns.barplot(x='Drivetrain', y='index', data=df.Drivetrain.value_counts().reset_index())

# %%
ax = sns.barplot(y='Drivetrain', x='index', data=df.Drivetrain.value_counts().reset_index())
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Front-Wheel Drive'),
#  Text(0, 0, 'Rear-Wheel Drive'),
#  Text(0, 0, '4-Wheel or All-Wheel Drive'),
#  Text(0, 0, 'All-Wheel Drive'),
#  Text(0, 0, '4-Wheel Drive'),
#  Text(0, 0, '2-Wheel Drive'),
#  Text(0, 0, 'Part-time 4-Wheel Drive'),
#  Text(0, 0, '2-Wheel Drive, Front')]

# %%
sns.dogplot()
