# %%
import pandas as pd
import numpy as np
import json


from pandas.io.json import json_normalize

# %%
movies = pd.read_csv('metamovie.csv')

# %%
movies
# Out:
#       Unnamed: 0  Unnamed: 0.1    imdb_id      revenue1         budget1  \
# 0              0             0  tt0114709  $406,594,102     $30,000,000
# 1              1             1  tt0113497  $262,821,940     $65,000,000
# 2              2             2  tt0113228   $71,518,503     $25,000,000
# 3              3             3  tt0114885   $81,452,156     $16,000,000
# 4              4             4  tt0113041   $76,594,107     $30,000,000
# 5              5             5  tt0113277  $187,436,818     $60,000,000
# 6              6             6  tt0114319   $53,672,080     $58,000,000
# 7              8             8  tt0114576   $64,350,171     $35,000,000
# 8              9             9  tt0113189  $352,194,034     $60,000,000
# 9             10            10  tt0112346  $107,879,496     $62,000,000
# 10            11            11  tt0112896   $10,772,144     $30,000,000
# 11            13            13  tt0113987   $13,681,765     $44,000,000
# ...

# %%
movies['revenue'] =pd.DataFrame([i.replace('$', '') for i in movies.revenue1])
#for i in movies.revenue1:
    #j = i.replace('$', '')
    #print(j)

# %%
movies['budget'] = pd.DataFrame([i.replace('$', '') for i in movies.budget1])

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'imdb_id', 'revenue1', 'budget1',
#        'Cast 1', 'Cast 2', 'adult', 'popularity', 'vote_average', 'vote_count',
#        'movie_id', 'production_countries', 'production_companies',
#        'release_date', 'genres', 'revenue', 'budget'],
#       dtype='object')

# %%
movies1 = movies[['imdb_id', 
       'Cast 1', 'Cast 2', 'adult', 'popularity', 'vote_average', 'vote_count',
       'movie_id', 'production_countries', 'production_companies',
       'release_date', 'genres', 'revenue', 'budget']]

# %%
movies1
# Out:
#         imdb_id    Cast 1    Cast 2  adult  popularity  vote_average  \
# 0     tt0114709  Moderate       Low  False   21.946943           7.7
# 1     tt0113497  Moderate       NaN  False   17.015539           6.9
# 2     tt0113228       Low  Moderate  False   11.712900           6.5
# 3     tt0114885       Low       Low  False    3.859495           6.1
# 4     tt0113041       Low       Low  False    8.387519           5.7
# 5     tt0113277  Moderate      High  False   17.924927           7.7
# 6     tt0114319       Low       Low  False    6.677277           6.2
# 7     tt0114576  Moderate       Low  False    5.231580           5.5
# 8     tt0113189       Low       Low  False   14.686036           6.6
# 9     tt0112346       Low       Low  False    6.318445           6.5
# 10    tt0112896       Low       Low  False    5.430331           5.7
# 11    tt0113987  Moderate       Low  False    5.092000           7.1
# 12    tt0112760       Low       Low  False    7.284477           5.7
# ...
